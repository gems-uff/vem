# %%
from scholarly import scholarly, ProxyGenerator, MaxTriesExceededException
from unidecode import unidecode
import pandas as pd
import time
from random import randint
import pylcs

SIMILARITY_THRESHOLD = 0.9

# reads papers from Excel file
df = pd.read_excel("publications.xlsx")

# %%
# Uses proxy to avoid Google Scholar blocking the requests
pg = ProxyGenerator()
success = pg.FreeProxies()
scholarly.use_proxy(pg)
print(f'Proxy: {success}.')
# Out:
# Proxy: True.

# %%
for index, row in df.iterrows():
    original_title = unidecode(row['title'].lower())  # Removes accents and upper case letters
 
    pubs = None
    while not pubs:
        try:  # Tries to run the query
            pubs = scholarly.search_pubs(row['title'])
        except MaxTriesExceededException:
            try:
                pg.get_next_proxy()  # Gets a new proxy if the query fails
                print(f'Current proxy failed. Trying a new one.')
            except StopIteration:
                pg = ProxyGenerator()
                success = pg.FreeProxies()
                scholarly.use_proxy(pg)
                print(f'All proxies failed. New proxy list: {success}.')

    try:  # Tries to get the title of the first result (the most similar result)
        pub = next(pubs)
        scholar_title = unidecode(pub['bib']['title'].lower())  # Removes accents and upper case letters
    except StopIteration:  # Ignores if there is no result
        scholar_title = ''

    # Check whether both titles are similar using LCS algorithm and sets the citation count accordingly
    similarity = 2.0 * pylcs.lcs_sequence_length(original_title, scholar_title) / (len(original_title) + len(scholar_title))
    citations = int(pub['num_citations']) if similarity >= SIMILARITY_THRESHOLD else 0
    df.at[index, 'citations'] = citations

    # Prints the results for auditing
    print(f'[{index + 1}/{len(df)}] Similarity: {similarity}. Citations: {citations}.')
    print(f'Original title: {original_title}')
    print(f'Scholar title:  {scholar_title}\n')
    time.sleep(randint(3, 7))  # Sleeps for around 5 seconds to avoig Google Scholar blocking the queries
# Out:
# Current proxy failed. Trying a new one.
# [1/231] Similarity: 1.0. Citations: 13.
# Original title: towards component-based software maintenance via software configuration management techniques
# Scholar title:  towards component-based software maintenance via software configuration management techniques
#
# [2/231] Similarity: 1.0. Citations: 8.
# Original title: documentacao essencial para manutencao de software ii
# Scholar title:  documentacao essencial para manutencao de software ii
#
# [3/231] Similarity: 0.9583333333333334. Citations: 4.
# Original title: evolucao orientada a aspectos de um framework oo
# Scholar title:  evolucao orientada a aspectos de um framework 00
#
# [4/231] Similarity: 1.0. Citations: 6.
# Original title: an evolution process for application frameworks
# Scholar title:  an evolution process for application frameworks
#
# [5/231] Similarity: 1.0. Citations: 6.
# Original title: uma experiencia no ensino de manutencao de software
# Scholar title:  uma experiencia no ensino de manutencao de software
#
# Current proxy failed. Trying a new one.
# [6/231] Similarity: 1.0. Citations: 2.
# Original title: identificacao de padroes arquiteturais usando engenharia reversa
# Scholar title:  identificacao de padroes arquiteturais usando engenharia reversa
#
# [7/231] Similarity: 1.0. Citations: 19.
# Original title: software architecture recovery based on dynamic analysis
# Scholar title:  software architecture recovery based on dynamic analysis
#
# [8/231] Similarity: 0.35428571428571426. Citations: 0.
# Original title: manutencao de sistemas oo utilizando a oa
# Scholar title:  modelo multicriterio de apoio a decisao para o planejamento de manutencao preventiva utilizando promethee ii em situacoes de incerteza
#
# [9/231] Similarity: 1.0. Citations: 3.
# Original title: uma abordagem de evolucao de sistemas orientados a objetos apoiada por frameworks transversais
# Scholar title:  uma abordagem de evolucao de sistemas orientados a objetos apoiada por frameworks transversais
#
# [10/231] Similarity: 1.0. Citations: 3.
# Original title: um conjunto de heuristicas de agrupamento de classes para apoiar a recuperacao da arquitetura de software
# Scholar title:  um conjunto de heuristicas de agrupamento de classes para apoiar a recuperacao da arquitetura de software
#
# [11/231] Similarity: 0.993006993006993. Citations: 1.
# Original title: iteradores, templates e consultas na analise e manipulacao de programas
# Scholar title:  iteradores, templates e consultas na analise e manipulac ao de programas
#
# [12/231] Similarity: 1.0. Citations: 3.
# Original title: criterios de avaliacao para reengenharia de sistemas legados
# Scholar title:  criterios de avaliacao para reengenharia de sistemas legados
#
# [13/231] Similarity: 1.0. Citations: 5.
# Original title: controle de modificacoes em software no desenvolvimento baseado em componentes
# Scholar title:  controle de modificacoes em software no desenvolvimento baseado em componentes
#
# [14/231] Similarity: 0.9951219512195122. Citations: 4.
# Original title: apoio a manutencao de software atraves de design rationale em ambientes de manutencao de software taba
# Scholar title:  apoio a manutencao de software atraves de design rationale em amb ientes de manutencao de software taba
#
# [15/231] Similarity: 0.627906976744186. Citations: 0.
# Original title: uma abordagem para controlar projetos de manutencao de produtos de software em uma pequena empresa
# Scholar title:  uma abordagem para o processo de gerenciamento de configuracao de software
#
# [16/231] Similarity: 0.5108695652173914. Citations: 0.
# Original title: uma experiencia na refatoracao do projeto e codigo-fonte de software para world wide web desenvolvido com php
# Scholar title:  proposta de metodo de reengenharia de sistemas legados desenvolvidos em php
#
# [17/231] Similarity: 1.0. Citations: 0.
# Original title: sistema de geracao de sitios e manutencao de conteudo: uma solucao incorporando regras de acessibilidade
# Scholar title:  sistema de geracao de sitios e manutencao de conteudo: uma solucao incorporando regras de acessibilidade
#
# [18/231] Similarity: 0.9922480620155039. Citations: 0.
# Original title: o ensino de manutencao de software baseado no meta- modelo da eml
# Scholar title:  o ensino de manutencao de software baseado no meta-modelo da eml
#
# [19/231] Similarity: 1.0. Citations: 0.
# Original title: recuperando modelos de dominio no contexto da engenharia reversa de software: um estudo de caso
# Scholar title:  recuperando modelos de dominio no contexto da engenharia reversa de software: um estudo de caso
#
# [20/231] Similarity: 1.0. Citations: 9.
# Original title: problemas em manutencao de software: caracterizacao e evolucao
# Scholar title:  problemas em manutencao de software: caracterizacao e evolucao
#
# [21/231] Similarity: 1.0. Citations: 3.
# Original title: estimativas de manutencao de software a partir de casos de uso
# Scholar title:  estimativas de manutencao de software a partir de casos de uso
#
# [22/231] Similarity: 0.40764331210191085. Citations: 0.
# Original title: redox-uml: redocumentacao de aplicacoes legadas cobol usando xml e uml
# Scholar title:  estudo comparativo de ferramentas de analise estatica no contexto de engenharia reversa
#
# [23/231] Similarity: 0.9795918367346939. Citations: 1.
# Original title: socrates - sistema orientado a objetos para caracterizacao de refatoracoes
# Scholar title:  socrates: sistema orientado a objetos para caracterizacao de refatoracoes
#
# [24/231] Similarity: 0.9955156950672646. Citations: 2.
# Original title: estudos experimentais em manutencao de software: observando decaimento de software atraves de modelos dinamicos
# Scholar title:  estudos experimentais em manutencao de sof-tware: observando decaimento de software atraves de modelos dinamicos
#
# All proxies failed. New proxy list: True.
# [25/231] Similarity: 1.0. Citations: 0.
# Original title: manutencao corretiva baseada em padroes e antipadroes de casos de uso
# Scholar title:  manutencao corretiva baseada em padroes e antipadroes de casos de uso
#
# [26/231] Similarity: 1.0. Citations: 1.
# Original title: personalizacao do processo gestao de configuracao de software para projetos de manutencao
# Scholar title:  personalizacao do processo gestao de configuracao de software para projetos de manutencao
#
# Current proxy failed. Trying a new one.
# [27/231] Similarity: 0.42592592592592593. Citations: 0.
# Original title: evolucao da complexidade de tres sistemas legados
# Scholar title:  conhecendo sistemas legados atraves de metricas de software
#
# Current proxy failed. Trying a new one.
# [28/231] Similarity: 0.4578313253012048. Citations: 0.
# Original title: estudo quantitativo da manutencao evolutiva em dois sistemas de codigo aberto
# Scholar title:  avaliando a divida tecnica em produtos de codigo aberto por meio de estudos experimentais
#
# [29/231] Similarity: 1.0. Citations: 0.
# Original title: avaliacao didatica de aderencia do processo de gerencia de solicitacao de mudancas de software
# Scholar title:  avaliacao didatica de aderencia do processo de gerencia de solicitacao de mudancas de software
#
# [30/231] Similarity: 0.9921259842519685. Citations: 0.
# Original title: licoes aprendidas no processode manutencao do ambiente webapsee
# Scholar title:  licoes aprendidas no processo de manutencao do ambiente webapsee
#
# [31/231] Similarity: 1.0. Citations: 1.
# Original title: uma experiencia em estimativas de projetos de manutencao de software
# Scholar title:  uma experiencia em estimativas de projetos de manutencao de software
#
# [32/231] Similarity: 1.0. Citations: 0.
# Original title: compreensao de programas apoiada por uma linguagem de consulta em codigo fonte
# Scholar title:  compreensao de programas apoiada por uma linguagem de consulta em codigo fonte
#
# [33/231] Similarity: 1.0. Citations: 0.
# Original title: integrated approach for framework-based system redesign
# Scholar title:  integrated approach for framework-based system redesign
#
# [34/231] Similarity: 0.9942196531791907. Citations: 4.
# Original title: uma abordagem sistematica para reutilizacao e versionamento de componentes de software
# Scholar title:  uma abordagem sistematica para reutilizac ao e versionamento de componentes de software
#
# [35/231] Similarity: 1.0. Citations: 0.
# Original title: compreensao de programas atraves da localizacao de casos de uso
# Scholar title:  compreensao de programas atraves da localizacao de casos de uso
#
# [36/231] Similarity: 1.0. Citations: 0.
# Original title: redox-uml: uma visao atualizada
# Scholar title:  redox-uml: uma visao atualizada
#
# [37/231] Similarity: 1.0. Citations: 1.
# Original title: um modelo de redocumentacao incremental de requisitos de sistemas legados utilizando casos de uso
# Scholar title:  um modelo de redocumentacao incremental de requisitos de sistemas legados utilizando casos de uso
#
# [38/231] Similarity: 1.0. Citations: 3.
# Original title: um estudo exploratorio sobre os efeitos da refatoracao na coordenacao das atividades de desenvolvimento de software livre
# Scholar title:  um estudo exploratorio sobre os efeitos da refatoracao na coordenacao das atividades de desenvolvimento de software livre
#
# [39/231] Similarity: 1.0. Citations: 0.
# Original title: criterios de manutenibilidade para construcao de produtos de software orientados a aspectos
# Scholar title:  criterios de manutenibilidade para construcao de produtos de software orientados a aspectos
#
# All proxies failed. New proxy list: True.
# [40/231] Similarity: 1.0. Citations: 1.
# Original title: analise do espalhamento de caracteristicas pela interpretacao visual de rastros de execucao
# Scholar title:  analise do espalhamento de caracteristicas pela interpretacao visual de rastros de execucao
#
# [41/231] Similarity: 1.0. Citations: 2.
# Original title: assessing program comprehension tools with the communicability evaluation method
# Scholar title:  assessing program comprehension tools with the communicability evaluation method
#
# Current proxy failed. Trying a new one.
# [42/231] Similarity: 1.0. Citations: 1.
# Original title: archjava: reconhecimento de padroes arquiteturais em sistemas java
# Scholar title:  archjava: reconhecimento de padroes arquiteturais em sistemas java
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [43/231] Similarity: 0.36809815950920244. Citations: 0.
# Original title: manutencao de sistemas desenvolvidos utilizando desenvolvimento guiado por testes
# Scholar title:  grenj: um framework obtido por um processo iterativo de reengenharia aplicando tdd
#
# Current proxy failed. Trying a new one.
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [44/231] Similarity: 1.0. Citations: 1.
# Original title: manutencao e evolucao de um gerador de aplicacoes desenvolvido com linha de produtos de software
# Scholar title:  manutencao e evolucao de um gerador de aplicacoes desenvolvido com linha de produtos de software
#
# [45/231] Similarity: 1.0. Citations: 1.
# Original title: uma estrategia de reestruturacao de modelos baseada em metricas para apoiar a reengenharia de software orientado a objetos para componentes
# Scholar title:  uma estrategia de reestruturacao de modelos baseada em metricas para apoiar a reengenharia de software orientado a objetos para componentes
#
# [46/231] Similarity: 0.40601503759398494. Citations: 0.
# Original title: manutencao de codigo apoiada pela ferramenta crista
# Scholar title:  crista: um apoio computacional para atividades de inspecao e compreensao de codigo
#
# [47/231] Similarity: 0.4380952380952381. Citations: 0.
# Original title: an infrastructure for maintenance and evolution of security and dependability in dynamic computing scenarios
# Scholar title:  foggy clouds and cloudy fogs: a real need for coordinated management of fog-to-cloud computing systems
#
# Current proxy failed. Trying a new one.
# [48/231] Similarity: 0.3516483516483517. Citations: 0.
# Original title: uma ferramenta para controle de modificacao de software: disen-chanco
# Scholar title:  prefacio e organizacao
#
# Current proxy failed. Trying a new one.
# All proxies failed. New proxy list: True.
# [49/231] Similarity: 0.8307692307692308. Citations: 0.
# Original title: uma proposta de criterios de manutenibilidade para modelos de projetos de software orientados a aspectos
# Scholar title:  criterios de manutenibilidade para construcao de produtos de software orientados a aspectos
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [50/231] Similarity: 1.0. Citations: 2.
# Original title: estimativa de metricas de separacao de interesses em processos de refatoracao para extracao de aspectos
# Scholar title:  estimativa de metricas de separacao de interesses em processos de refatoracao para extracao de aspectos
#
# Current proxy failed. Trying a new one.
# [51/231] Similarity: 0.41706161137440756. Citations: 0.
# Original title: reestruturacao de um framework de aplicacao com um framework transversal de persistencia
# Scholar title:  frameworks transversais: definicoes, classificacoes, arquitetura e utilizacao em um processo de desenvolvimento de software
#
# [52/231] Similarity: 0.7717391304347826. Citations: 0.
# Original title: modelagem, implementacao e manutencao de regras de negocio em sistemas de informacao
# Scholar title:  arquitetura e implementacao de mecanismos para suporte a regras de negocio em sistemas de informacao
#
# [53/231] Similarity: 1.0. Citations: 3.
# Original title: design suite: towards an open scientific investigation environment for software architecture recovery
# Scholar title:  design suite: towards an open scientific investigation environment for software architecture recovery
#
# [54/231] Similarity: 0.2692307692307692. Citations: 0.
# Original title: engenharia reversa para recuperacao de modelos de sistemas desenvolvidos em pl/sql
# Scholar title:  prefacio e organizacao
#
# [55/231] Similarity: 1.0. Citations: 6.
# Original title: an iterative reengineering process applying test-driven development and reverse engineering patterns
# Scholar title:  an iterative reengineering process applying test-driven development and reverse engineering patterns
#
# [56/231] Similarity: 0.41379310344827586. Citations: 0.
# Original title: analise de artefatos de teste
# Scholar title:  protecao cibernetica: proposta de um laboratorio para analise de artefatos ciberneticos
#
# [57/231] Similarity: 0.2909090909090909. Citations: 0.
# Original title: desafio: produzir e evoluir software em escala para a conquista e manutencao de mercados
# Scholar title:  prefacio e organizacao
#
# [58/231] Similarity: 1.0. Citations: 1.
# Original title: modelo de gestao de demandas de manutencao de software: a experiencia da puc minas
# Scholar title:  modelo de gestao de demandas de manutencao de software: a experiencia da puc minas
#
# [59/231] Similarity: 0.989010989010989. Citations: 0.
# Original title: uma meta-ferramenta para deteccao de defeitos
# Scholar title:  uma meta-ferramenta para detecc ao de defeitos
#
# [60/231] Similarity: 1.0. Citations: 4.
# Original title: definicao de padroes arquiteturais e seu impacto em atividades de manutencao de software
# Scholar title:  definicao de padroes arquiteturais e seu impacto em atividades de manutencao de software
#
# [61/231] Similarity: 0.0. Citations: 0.
# Original title: comscid - um apoio computacional customizavel para identificacao de interesses transversais em sistemas legados orientados a objetos
# Scholar title:
#
# [62/231] Similarity: 1.0. Citations: 2.
# Original title: um processo de implantacao de gerencia de configuracao na industria
# Scholar title:  um processo de implantacao de gerencia de configuracao na industria
#
# [63/231] Similarity: 1.0. Citations: 2.
# Original title: verificacao de aderencia entre arquiteturas conceituais e emergentes utilizando a abordagem previa
# Scholar title:  verificacao de aderencia entre arquiteturas conceituais e emergentes utilizando a abordagem previa
#
# [64/231] Similarity: 0.4294478527607362. Citations: 0.
# Original title: observando evolucao de software atraves de modelos dinamicos
# Scholar title:  jornalismo digital em base de dados (jdbd): um paradigma para produtos jornalisticos digitais dinamicos
#
# [65/231] Similarity: 0.5198237885462555. Citations: 0.
# Original title: integracao de ferramentas para minimizar erros provenientes de efeitos colaterais inseridos durante a manutencao
# Scholar title:  implantacao de uma ferramenta de integracao continua em um nucleo de praticas em informatica: relato de experiencia
#
# [66/231] Similarity: 0.4378698224852071. Citations: 0.
# Original title: manutencao de frameworks orientados a objetos usando orientacao a aspectos
# Scholar title:  uso de aspectos para apoiar a evolucao nao funcional de frameworks: aplicacao ao framework gren
#
# [67/231] Similarity: 1.0. Citations: 5.
# Original title: on the design of a multi-perspective visualization environment to enhance software comprehension activities
# Scholar title:  on the design of a multi-perspective visualization environment to enhance software comprehension activities
#
# [68/231] Similarity: 0.4918032786885246. Citations: 0.
# Original title: metrics and detection of bad smells on annotated codes
# Scholar title:  detecting bad smells in source code using change history information
#
# [69/231] Similarity: 1.0. Citations: 0.
# Original title: ampliando o apoio a comparacao de artefatos via aplicacao recursiva do algoritmo de lcs
# Scholar title:  ampliando o apoio a comparacao de artefatos via aplicacao recursiva do algoritmo de lcs
#
# [70/231] Similarity: 1.0. Citations: 0.
# Original title: caracterizando programadores iniciantes na identificacao de anomalias de modularidade: um estudo inicial
# Scholar title:  caracterizando programadores iniciantes na identificacao de anomalias de modularidade: um estudo inicial
#
# [71/231] Similarity: 0.9937106918238994. Citations: 0.
# Original title: fatores que afetam a qualidade do codigo-fonte: a percepcao dos desenvolvedores
# Scholar title:  fatores que afetam a qualidade do codigo-fonte: a percepc ao dos desenvolvedores
#
# [72/231] Similarity: 0.4. Citations: 0.
# Original title: a case study on the similarity between source code and bug reports vocabularies
# Scholar title:  assigning bug reports using a vocabulary-based expertise model of developers
#
# [73/231] Similarity: 1.0. Citations: 0.
# Original title: understanding the occurrence of vocabulary terms in java code
# Scholar title:  understanding the occurrence of vocabulary terms in java code
#
# [74/231] Similarity: 1.0. Citations: 0.
# Original title: comscid: identificacao automatica de interesses em sistemas orientados a objetos
# Scholar title:  comscid: identificacao automatica de interesses em sistemas orientados a objetos
#
# [75/231] Similarity: 0.7701149425287356. Citations: 0.
# Original title: visualizando relacionamento entre modulos de software usando grafos aninhados
# Scholar title:  visualizando relacionamento entre modulos de software baseado em metricas de acoplamento e coesao
#
# [76/231] Similarity: 1.0. Citations: 8.
# Original title: an approach for extracting modules from monolithic software architectures
# Scholar title:  an approach for extracting modules from monolithic software architectures
#
# [77/231] Similarity: 0.6326530612244898. Citations: 0.
# Original title: deteccao semantica de clones a partir de bytecodes
# Scholar title:  deteccao interprocedimental de clones semanticos
#
# [78/231] Similarity: 0.45871559633027525. Citations: 0.
# Original title: integracao de metricas estaticas e dinamicas para apoiar a avaliacao da qualidade em modelos de software
# Scholar title:  avaliacao de qualidade de software baseada em metricas estaticas: um estudo de caso no tribunal de contas da uniao
#
# [79/231] Similarity: 1.0. Citations: 1.
# Original title: acompanhamento da evolucao de software via metricas
# Scholar title:  acompanhamento da evolucao de software via metricas
#
# [80/231] Similarity: 1.0. Citations: 4.
# Original title: supporting software maintenance activities through a software visualization product line infrastructure
# Scholar title:  supporting software maintenance activities through a software visualization product line infrastructure
#
# [81/231] Similarity: 0.45685279187817257. Citations: 0.
# Original title: estrategias e perfis de programadores iniciantes na identificacao de anomalias de modularidade de software
# Scholar title:  um experimento na industria para mineracao visual de padroes de interacoes de programadores
#
# [82/231] Similarity: 1.0. Citations: 3.
# Original title: ivar: a conceptual framework for dependency management
# Scholar title:  ivar: a conceptual framework for dependency management
#
# [83/231] Similarity: 1.0. Citations: 2.
# Original title: avaliacao da integracao de aplicacoes empresariais usando web services: um estudo empirico
# Scholar title:  avaliacao da integracao de aplicacoes empresariais usando web services: um estudo empirico
#
# [84/231] Similarity: 1.0. Citations: 2.
# Original title: uma proposta de multiplas visoes coordenadas para apoiar analise de impacto de mudanca
# Scholar title:  uma proposta de multiplas visoes coordenadas para apoiar analise de impacto de mudanca
#
# [85/231] Similarity: 0.4358974358974359. Citations: 0.
# Original title: uma abordagem para classificacao de construcao de software utilizando redes de comunicacao e cooperacao
# Scholar title:  um modelo de desenvolvimento de sistemas para suporte a cooperacao fundamentado em design participativo e semiotica organizacional.
#
# [86/231] Similarity: 1.0. Citations: 2.
# Original title: profap: processo colaborativo de manutencao de software
# Scholar title:  profap: processo colaborativo de manutencao de software
#
# [87/231] Similarity: 1.0. Citations: 0.
# Original title: metamodelo para integracao de ferramentas de mineracao de interesses transversais e de visualizacao de software
# Scholar title:  metamodelo para integracao de ferramentas de mineracao de interesses transversais e de visualizacao de software
#
# [88/231] Similarity: 1.0. Citations: 8.
# Original title: recommendations for context-aware visualizations in software development
# Scholar title:  recommendations for context-aware visualizations in software development
#
# [89/231] Similarity: 0.8448275862068966. Citations: 0.
# Original title: um panorama das ferramentas de visualizacao de software
# Scholar title:  o estado-da-arte das ferramentas de visualizacao de software.
#
# [90/231] Similarity: 1.0. Citations: 4.
# Original title: on the use of a multiple-visualization approach to manage software bugs
# Scholar title:  on the use of a multiple-visualization approach to manage software bugs
#
# [91/231] Similarity: 0.36486486486486486. Citations: 0.
# Original title: reutilizacao de ativos em aplicacoes de visualizacao 3d
# Scholar title:  uma arquitetura de referencia para gerenciamento e reuso de ambientes virtuais tridmensionais
#
# [92/231] Similarity: 1.0. Citations: 0.
# Original title: graphvcs: uma abordagem para a visualizacao e compreensao de repositorios de controle de versao
# Scholar title:  graphvcs: uma abordagem para a visualizacao e compreensao de repositorios de controle de versao
#
# [93/231] Similarity: 1.0. Citations: 9.
# Original title: evoltrack: a plug-in-based infrastructure for visualizing software evolution
# Scholar title:  evoltrack: a plug-in-based infrastructure for visualizing software evolution
#
# [94/231] Similarity: 0.45544554455445546. Citations: 0.
# Original title: visualizacao da evolucao de software com xflow: integrando aspectos tecnicos e sociais em multiplas visualizacoes
# Scholar title:  identificacao e visualizacao de dependencias em sistemas de software orientados a objetos
#
# [95/231] Similarity: 1.0. Citations: 4.
# Original title: coordinated visualization of aspect-oriented programs
# Scholar title:  coordinated visualization of aspect-oriented programs
#
# [96/231] Similarity: 1.0. Citations: 5.
# Original title: propondo uma arquitetura para ambientes interativos baseados em multiplas visoes
# Scholar title:  propondo uma arquitetura para ambientes interativos baseados em multiplas visoes
#
# [97/231] Similarity: 0.9924812030075187. Citations: 6.
# Original title: timeline matrix: an on demand view for software evolution analysis.
# Scholar title:  timeline matrix: an on demand view for software evolution analysis
#
# All proxies failed. New proxy list: True.
# [98/231] Similarity: 1.0. Citations: 24.
# Original title: skyscrapar: an augmented reality visualization for software evolution
# Scholar title:  skyscrapar: an augmented reality visualization for software evolution
#
# [99/231] Similarity: 1.0. Citations: 0.
# Original title: aplicacao de uma tecnica de visualizacao de dados baseado em arvores para auxiliar a priorizacao de requisitos em projetos ageis
# Scholar title:  aplicacao de uma tecnica de visualizacao de dados baseado em arvores para auxiliar a priorizacao de requisitos em projetos ageis
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [100/231] Similarity: 1.0. Citations: 1.
# Original title: um experimento na industria para mineracao visual de padroes de interacoes de programadores
# Scholar title:  um experimento na industria para mineracao visual de padroes de interacoes de programadores
#
# [101/231] Similarity: 0.9513888888888888. Citations: 0.
# Original title: usando recursos de visualizacao enriquecidos com elementos de percepcao para a compreensao de software em um ambiente de desenvolvimento distribuido
# Scholar title:  usando recursos de visualizacao enriquecidos com elementos de percepcao para a compreensao de software em um ambiente de desenvolvimento ...
#
# Current proxy failed. Trying a new one.
# [102/231] Similarity: 1.0. Citations: 0.
# Original title: what is going on around my repository?
# Scholar title:  what is going on around my repository?
#
# [103/231] Similarity: 1.0. Citations: 2.
# Original title: tipar ou nao tipar? compreendendo quais fatores influenciam a escolha por um sistema de tipos
# Scholar title:  tipar ou nao tipar? compreendendo quais fatores influenciam a escolha por um sistema de tipos
#
# [104/231] Similarity: 0.4622222222222222. Citations: 0.
# Original title: verificacao de conformidade arquitetural com testes de design - um estudo de caso
# Scholar title:  testes de design: uma abordagem baseada em testes para verificacao automatica de conformidade estrutural entre implementacao e regras de design.
#
# [105/231] Similarity: 1.0. Citations: 0.
# Original title: changeminer: um plug-in visual para auxiliar a manutencao de software
# Scholar title:  changeminer: um plug-in visual para auxiliar a manutencao de software
#
# [106/231] Similarity: 0.9949238578680203. Citations: 0.
# Original title: visualizacao de software como suporte ao desenvolvimento centrado em metricas orientadas a objetos
# Scholar title:  visualizac ao de software como suporte ao desenvolvimento centrado em metricas orientadas a objetos
#
# [107/231] Similarity: 1.0. Citations: 1.
# Original title: reusedashboard: apoiando stakeholders na monitoracao de programas de reutilizacao de software
# Scholar title:  reusedashboard: apoiando stakeholders na monitoracao de programas de reutilizacao de software
#
# [108/231] Similarity: 0.9883720930232558. Citations: 1.
# Original title: uma abordagem baseada em eventos para adaptacao automatica de aplicacoes para a nuvem
# Scholar title:  uma abordagem baseada em eventos para adaptac ao automatica de aplicac oes para a nuvem
#
# [109/231] Similarity: 1.0. Citations: 5.
# Original title: what questions developers ask during software evolution? an academic perspective
# Scholar title:  what questions developers ask during software evolution? an academic perspective
#
# [110/231] Similarity: 1.0. Citations: 0.
# Original title: um estudo empirico do uso da comunicacao para caracterizar a ocorrencia de dependencias de mudanca no projeto ruby on rails
# Scholar title:  um estudo empirico do uso da comunicacao para caracterizar a ocorrencia de dependencias de mudanca no projeto ruby on rails
#
# [111/231] Similarity: 1.0. Citations: 3.
# Original title: analise de metricas estaticas para sistemas javascript
# Scholar title:  analise de metricas estaticas para sistemas javascript
#
# [112/231] Similarity: 0.9452054794520548. Citations: 0.
# Original title: migracao parcial de um banco de dados relacional para um banco de dados nosql na nuvem atraves de adaptacoes nao-intrusivas: um relato de experiencia
# Scholar title:  migrac ao parcial de um banco de dados relacional para um banco de dados nosql na nuvem atraves de adaptac oes nao-intrusivas: um relato de ...
#
# [113/231] Similarity: 1.0. Citations: 0.
# Original title: polimorphic view: visualizando o uso de polimorfismo em projetos de software
# Scholar title:  polimorphic view: visualizando o uso de polimorfismo em projetos de software
#
# [114/231] Similarity: 1.0. Citations: 1.
# Original title: on the use of context information for supporting software visualizations
# Scholar title:  on the use of context information for supporting software visualizations
#
# [115/231] Similarity: 0.9893617021276596. Citations: 1.
# Original title: archgraph: modularizacao automatica de sistemas usando clusterizacao de grafos de dependencia
# Scholar title:  archgraph: modularizac ao automatica de sistemas usando clusterizac ao de grafos de dependencia
#
# [116/231] Similarity: 0.9859154929577465. Citations: 2.
# Original title: simms - um jogo educacional de apoio ao ensino de manutencao de software
# Scholar title:  simms-um jogo educacional de apoio ao ensino de manutencao de software
#
# [117/231] Similarity: 1.0. Citations: 0.
# Original title: profap-r: um processo de reengenharia de codigo orientada pela reengenharia de dados
# Scholar title:  profap-r: um processo de reengenharia de codigo orientada pela reengenharia de dados
#
# [118/231] Similarity: 1.0. Citations: 5.
# Original title: influencing factors on code smells and software maintainability: a cross-case study
# Scholar title:  influencing factors on code smells and software maintainability: a cross-case study
#
# [119/231] Similarity: 1.0. Citations: 0.
# Original title: how developers deal with code smells: the case of the sourceminer evolution team
# Scholar title:  how developers deal with code smells: the case of the sourceminer evolution team
#
# [120/231] Similarity: 1.0. Citations: 0.
# Original title: um metodo para identificacao de bad smells a partir de diagramas de classes
# Scholar title:  um metodo para identificacao de bad smells a partir de diagramas de classes
#
# [121/231] Similarity: 1.0. Citations: 1.
# Original title: uma analise da historia do vem, wbvs e wmswm
# Scholar title:  uma analise da historia do vem, wbvs e wmswm
#
# [122/231] Similarity: 1.0. Citations: 3.
# Original title: kdm-re: a model-driven refactoring tool for kdm
# Scholar title:  kdm-re: a model-driven refactoring tool for kdm
#
# [123/231] Similarity: 1.0. Citations: 0.
# Original title: redocumentando apis com conhecimento da multidao: um estudo de cobertura da api swing no stack overflow
# Scholar title:  redocumentando apis com conhecimento da multidao: um estudo de cobertura da api swing no stack overflow
#
# [124/231] Similarity: 0.42696629213483145. Citations: 0.
# Original title: um estudo sobre a utilizacao de mensagens de depreciacao de apis
# Scholar title:  parametros fisico-quimicos propostos para o controle de qualidade do mel de abelhas indigenas sem ferrao no brasil
#
# [125/231] Similarity: 1.0. Citations: 18.
# Original title: experimental evaluation of code smell detection tools
# Scholar title:  experimental evaluation of code smell detection tools
#
# [126/231] Similarity: 1.0. Citations: 3.
# Original title: on mapping goals and visualizations: towards identifying and addressing information needs
# Scholar title:  on mapping goals and visualizations: towards identifying and addressing information needs
#
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [127/231] Similarity: 1.0. Citations: 4.
# Original title: using javascript static checkers on github systems: a first evaluation
# Scholar title:  using javascript static checkers on github systems: a first evaluation
#
# [128/231] Similarity: 0.9953488372093023. Citations: 1.
# Original title: avaliacao experimental da relacao entre coesao e o esforco de compreensao de programas: um estudo preliminar
# Scholar title:  avaliacao experimental da relacao entre coesao eo esforco de compreensao de programas: um estudo preliminar
#
# [129/231] Similarity: 1.0. Citations: 10.
# Original title: evaluation of duplicated code detection tools in cross-project context
# Scholar title:  evaluation of duplicated code detection tools in cross-project context
#
# [130/231] Similarity: 1.0. Citations: 1.
# Original title: boas e mas praticas no desenvolvimento web com mvc: resultados de um questionario com profissionais
# Scholar title:  boas e mas praticas no desenvolvimento web com mvc: resultados de um questionario com profissionais
#
# [131/231] Similarity: 0.5. Citations: 0.
# Original title: swarm debugging: towards a shared debugging knowledge
# Scholar title:  towards understanding interactive debugging
#
# [132/231] Similarity: 0.9690721649484536. Citations: 3.
# Original title: jscity: visualizacao de sistemas javascript em 3d
# Scholar title:  jscity-visualizacao de sistemas javascript em 3d
#
# Current proxy failed. Trying a new one.
# [133/231] Similarity: 1.0. Citations: 0.
# Original title: ecodroid: uma ferramenta para analise e visualizacao de consumo de energia em aplicativos android
# Scholar title:  ecodroid: uma ferramenta para analise e visualizacao de consumo de energia em aplicativos android
#
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [134/231] Similarity: 0.9629629629629629. Citations: 0.
# Original title: visminerservice: a rest web service for source mining
# Scholar title:  visminerservice oe a rest web service for source mining
#
# Current proxy failed. Trying a new one.
# [135/231] Similarity: 1.0. Citations: 118.
# Original title: towards a technique for extracting microservices from monolithic enterprise systems
# Scholar title:  towards a technique for extracting microservices from monolithic enterprise systems
#
# [136/231] Similarity: 0.37623762376237624. Citations: 0.
# Original title: software evolution sonification
# Scholar title:  orchestrating change: an artistic representation of software evolution
#
# [137/231] Similarity: 0.9940119760479041. Citations: 1.
# Original title: como o formato de arquivos xml evolui? um estudo sobre sua relacao com codigo-fonte
# Scholar title:  como o formato de arquivos xml evolui? um estudo sobre sua relac ao com codigo-fonte
#
# [138/231] Similarity: 0.9837837837837838. Citations: 0.
# Original title: distribuicao de conhecimento de codigo em times de desenvolvimento - uma analise arquitetural
# Scholar title:  distribuic ao de conhecimento de codigo em times de desenvolvimento-uma analise arquitetural
#
# [139/231] Similarity: 1.0. Citations: 0.
# Original title: uma analise preliminar de projetos de software livre que migraram para o github
# Scholar title:  uma analise preliminar de projetos de software livre que migraram para o github
#
# [140/231] Similarity: 1.0. Citations: 1.
# Original title: um estudo em larga escala sobre estabilidade de apis
# Scholar title:  um estudo em larga escala sobre estabilidade de apis
#
# Current proxy failed. Trying a new one.
# [141/231] Similarity: 1.0. Citations: 0.
# Original title: um estudo em larga escala sobre o uso de apis internas
# Scholar title:  um estudo em larga escala sobre o uso de apis internas
#
# [142/231] Similarity: 1.0. Citations: 0.
# Original title: dolly or shaun? a survey to verify code clones detected using similar sequences of method calls
# Scholar title:  dolly or shaun? a survey to verify code clones detected using similar sequences of method calls
#
# [143/231] Similarity: 0.994475138121547. Citations: 1.
# Original title: uma analise da associacao de co-ocorrencia de anomalias de codigo com metricas estruturais
# Scholar title:  uma analise da associac ao de co-ocorrencia de anomalias de codigo com metricas estruturais
#
# [144/231] Similarity: 1.0. Citations: 0.
# Original title: towards an approach to prevent long methods based on architecture-sensitive recommendations
# Scholar title:  towards an approach to prevent long methods based on architecture-sensitive recommendations
#
# [145/231] Similarity: 1.0. Citations: 0.
# Original title: uma ferramenta para conversao de codigo javascript orientado a objetos em ecma 5 para ecma 6
# Scholar title:  uma ferramenta para conversao de codigo javascript orientado a objetos em ecma 5 para ecma 6
#
# [146/231] Similarity: 1.0. Citations: 2.
# Original title: avaliacao heuristica de um ambiente virtual para analise de rotas de execucao de software
# Scholar title:  avaliacao heuristica de um ambiente virtual para analise de rotas de execucao de software
#
# [147/231] Similarity: 1.0. Citations: 6.
# Original title: sppv: visualizing software process provenance data
# Scholar title:  sppv: visualizing software process provenance data
#
# [148/231] Similarity: 1.0. Citations: 2.
# Original title: using evowave for logical coupling analysis of a long-lived software system
# Scholar title:  using evowave for logical coupling analysis of a long-lived software system
#
# [149/231] Similarity: 0.9821428571428571. Citations: 0.
# Original title: from formal results to uml model - a mda tracing approach
# Scholar title:  from formal results to uml model a mda tracing approach
#
# [150/231] Similarity: 1.0. Citations: 0.
# Original title: revelando extensoes de conceitos no codigo fonte
# Scholar title:  revelando extensoes de conceitos no codigo fonte
#
# [151/231] Similarity: 0.994413407821229. Citations: 4.
# Original title: inferencia de tipos em ruby: uma comparacao entre tecnicas de analise estatica e dinamica
# Scholar title:  inferencia de tipos em ruby: uma comparac ao entre tecnicas de analise estatica e dinamica
#
# [152/231] Similarity: 0.9902912621359223. Citations: 0.
# Original title: saramr: uma arquitetura de referencia para facilitar manutencoes em sistemas roboticos autoadaptativos
# Scholar title:  sara mr: uma arquitetura de referencia para facilitar manutenc oes em sistemas roboticos autoadaptativos
#
# [153/231] Similarity: 0.4166666666666667. Citations: 0.
# Original title: caracterizacao do papel desempenhado por desenvolvedores responsaveis pelo truck factor de projetos de software
# Scholar title:  metodos ageis e software livre: um estudo da relacao entre estas duas comunidades
#
# [154/231] Similarity: 1.0. Citations: 2.
# Original title: como pesquisadores usam o dataset ghtorrent?
# Scholar title:  como pesquisadores usam o dataset ghtorrent?
#
# [155/231] Similarity: 0.6190476190476191. Citations: 0.
# Original title: uma analise preliminar da hiperespecializacao no contexto de crowdsourcing na plataforma topcoder
# Scholar title:  um estudo empirico sobre crowdsourcing: o brasil na plataforma topcoder
#
# [156/231] Similarity: 0.9838709677419355. Citations: 9.
# Original title: who drive company-owned oss projects: employees or volunteers?
# Scholar title:  who drives company-owned oss projects: employees or volunteers
#
# [157/231] Similarity: 1.0. Citations: 7.
# Original title: do coupling metrics help characterize critical components in component-based spl? an empirical study
# Scholar title:  do coupling metrics help characterize critical components in component-based spl? an empirical study
#
# [158/231] Similarity: 1.0. Citations: 0.
# Original title: impactos de praticas de codificacao sobre a legibilidade: um estudo preliminar
# Scholar title:  impactos de praticas de codificacao sobre a legibilidade: um estudo preliminar
#
# [159/231] Similarity: 0.9950738916256158. Citations: 1.
# Original title: visminertd: uma ferramenta para identificacao automatica e monitoramento interativo de divida tecnica
# Scholar title:  visminertd: uma ferramenta para identificac ao automatica e monitoramento interativo de divida tecnica
#
# [160/231] Similarity: 0.9901960784313726. Citations: 0.
# Original title: vulnerabilidades em sistemas de software web baseados em plug-ins: um estudo exploratorio do wordpress
# Scholar title:  vulnerabilidades em sistemas de software web baseados em plug-ins? um estudo exploratorio do wordpress
#
# [161/231] Similarity: 1.0. Citations: 0.
# Original title: em busca de uma abordagem de conformidade arquitetural para arquitetura de microsservicos
# Scholar title:  em busca de uma abordagem de conformidade arquitetural para arquitetura de microsservicos
#
# [162/231] Similarity: 1.0. Citations: 1.
# Original title: arquitetura de aplicacoes spring mvc: uma analise baseada no acoplamento logico
# Scholar title:  arquitetura de aplicacoes spring mvc: uma analise baseada no acoplamento logico
#
# [163/231] Similarity: 0.9927007299270073. Citations: 0.
# Original title: uma caracterizacao em larga escala da arquitetura de sistemas docker
# Scholar title:  uma caracterizac ao em larga escala da arquitetura de sistemas docker
#
# [164/231] Similarity: 0.995850622406639. Citations: 0.
# Original title: usando aprendizagem de maquina para identificar anomalias de design prejudiciais a manutenibilidade: um estudo preliminar
# Scholar title:  usando aprendizagem de maquina para identificar anomalias de design prejudiciaisa manutenibilidade: um estudo preliminar
#
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# [165/231] Similarity: 0.9764705882352941. Citations: 0.
# Original title: mineracao de regras para solucao de problemas relacionados a fragmentacao do android
# Scholar title:  minerac ao de regras para soluc ao de problemas relacionadosa fragmentac ao do android
#
# [166/231] Similarity: 1.0. Citations: 3.
# Original title: definicao de clusters para classificacao do uso de anotacoes em codigo java
# Scholar title:  definicao de clusters para classificacao do uso de anotacoes em codigo java
#
# [167/231] Similarity: 1.0. Citations: 0.
# Original title: caracterizando o consumo de energia de apis de e/s da linguagem java
# Scholar title:  caracterizando o consumo de energia de apis de e/s da linguagem java
#
# [168/231] Similarity: 0.4631578947368421. Citations: 0.
# Original title: um estudo em larga-escala sobre caracteristicas de apis populares
# Scholar title:  gestao educacional e avaliacao em larga escala: um estudo a partir da visao dos sujeitos de escolas do municipio de canoas/rs
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [169/231] Similarity: 0.9947089947089947. Citations: 0.
# Original title: minerando mensagens de depreciacao faltantes em apis: um estudo de caso no ecossistema android
# Scholar title:  minerando mensagens de depreciac ao faltantes em apis: um estudo de caso no ecossistema android
#
# [170/231] Similarity: 1.0. Citations: 1.
# Original title: stf: uma abordagem social para estimar truck factor no github
# Scholar title:  stf: uma abordagem social para estimar truck factor no github
#
# [171/231] Similarity: 1.0. Citations: 0.
# Original title: heuristicas para identificacao de ambiguidade de autores em projetos open source
# Scholar title:  heuristicas para identificacao de ambiguidade de autores em projetos open source
#
# [172/231] Similarity: 1.0. Citations: 6.
# Original title: monorepos: a multivocal literature review
# Scholar title:  monorepos: a multivocal literature review
#
# [173/231] Similarity: 1.0. Citations: 0.
# Original title: minerando codigo comentado
# Scholar title:  minerando codigo comentado
#
# Current proxy failed. Trying a new one.
# [174/231] Similarity: 0.9927007299270073. Citations: 0.
# Original title: um estudo empirico sobre criterios de selecao de repositorios github
# Scholar title:  um estudo empirico sobre criterios de selec ao de repositorios github
#
# [175/231] Similarity: 1.0. Citations: 4.
# Original title: github rest api vs ghtorrent vs github archive: a comparative study
# Scholar title:  github rest api vs ghtorrent vs github archive: a comparative study
#
# [176/231] Similarity: 1.0. Citations: 43.
# Original title: microservices in practice: a survey study
# Scholar title:  microservices in practice: a survey study
#
# [177/231] Similarity: 0.47668393782383417. Citations: 0.
# Original title: um metodo para detectar similaridade entre sistemas baseado em decisoes de design: um estudo preliminar
# Scholar title:  um estudo preliminar sobre conceitos extrinsecos e intrinsecos do processo de gamification
#
# [178/231] Similarity: 0.8810572687224669. Citations: 0.
# Original title: comparando tecnicas de extracao de valores limiares para metricas: um estudo preliminar com desenvolvedores web
# Scholar title:  comparando tecnicas de extracao de valores limiares para metricas de codigo fonte: um estudo com desenvolvedores web
#
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [179/231] Similarity: 0.7655502392344498. Citations: 0.
# Original title: um estudo empirico sobre o impacto dos pre-processamentos e normalizacoes no calculo do acoplamento conceitual
# Scholar title:  estudo empirico sobre o impacto das configuracoes do processo de obtencao do acoplamento conceitual
#
# Current proxy failed. Trying a new one.
# [180/231] Similarity: 0.3803680981595092. Citations: 0.
# Original title: violacao de padroes de uso de apis em sistemas configuraveis
# Scholar title:  safe h-kaas: uma estrategia para protecao contra violacao de conhecimento em kaas no dominio da e-saude
#
# [181/231] Similarity: 0.4818181818181818. Citations: 0.
# Original title: avaliacao da frequencia de mudancas em dependencias entre variabilidades em sistemas configuraveis
# Scholar title:  medidas para avaliacao da manutenibilidade do modelo de features de linhas de produto de software tradicionais e dinamicas
#
# Current proxy failed. Trying a new one.
# All proxies failed. New proxy list: True.
# [182/231] Similarity: 0.39285714285714285. Citations: 0.
# Original title: vmag 3d - an approach for supporting the comprehension of software system models using motion control in a multiuser 3d visualization environment
# Scholar title:  implementation of three-dimensional visualization in interactive web-based environment for engineering education and technical training
#
# [183/231] Similarity: 0.9863013698630136. Citations: 0.
# Original title: development and maintenance of model-oriented software with visualization - exploratory and experimental study
# Scholar title:  development and maintenance of model-oriented software with visualization: exploratory and experimental study
#
# [184/231] Similarity: 0.9849246231155779. Citations: 0.
# Original title: uma analise da producao cientifica brasileira em conferencias de manutencao e evolucao de software
# Scholar title:  uma analise da produc ao cientifica brasileira em conferencias de manutenc ao e evoluc ao de software
#
# [185/231] Similarity: 1.0. Citations: 2.
# Original title: an infrastructure for software release analysis through provenance graphs
# Scholar title:  an infrastructure for software release analysis through provenance graphs
#
# [186/231] Similarity: 1.0. Citations: 0.
# Original title: uma tecnica para a quantificacao do esforco de merge
# Scholar title:  uma tecnica para a quantificacao do esforco de merge
#
# [187/231] Similarity: 1.0. Citations: 14.
# Original title: towards an automated approach for bug fix pattern detection
# Scholar title:  towards an automated approach for bug fix pattern detection
#
# [188/231] Similarity: 0.46540880503144655. Citations: 0.
# Original title: explorando como bibliotecas python lancam excecoes ao longo de sua evolucao
# Scholar title:  avaliando a robustez e manutenibilidade do comportamento excepcional de aplicacoes c
#
# [189/231] Similarity: 1.0. Citations: 5.
# Original title: identifying confusing code in swift programs
# Scholar title:  identifying confusing code in swift programs
#
# [190/231] Similarity: 1.0. Citations: 1.
# Original title: diffmutanalyze: uma abordagem para auxiliar a identificacao de mutantes equivalentes
# Scholar title:  diffmutanalyze: uma abordagem para auxiliar a identificacao de mutantes equivalentes
#
# [191/231] Similarity: 1.0. Citations: 2.
# Original title: how do technical factors affect developers in mobile software ecosystems
# Scholar title:  how do technical factors affect developers in mobile software ecosystems
#
# [192/231] Similarity: 1.0. Citations: 3.
# Original title: uma investigacao da aplicacao de aprendizado de maquina para deteccao de smells arquiteturais
# Scholar title:  uma investigacao da aplicacao de aprendizado de maquina para deteccao de smells arquiteturais
#
# [193/231] Similarity: 1.0. Citations: 0.
# Original title: o impacto da utilizacao da ferramenta pivotal tracker para monitoracao de desempenho em times ageis de desenvolvimento de software
# Scholar title:  o impacto da utilizacao da ferramenta pivotal tracker para monitoracao de desempenho em times ageis de desenvolvimento de software
#
# [194/231] Similarity: 1.0. Citations: 0.
# Original title: um estudo preliminar sobre o uso de uma arquitetura deep learning para selecao de respostas no problema de recuperacao de codigo-fonte
# Scholar title:  um estudo preliminar sobre o uso de uma arquitetura deep learning para selecao de respostas no problema de recuperacao de codigo-fonte
#
# [195/231] Similarity: 1.0. Citations: 3.
# Original title: analise de sentimentos em discussoes de issues reabertas do github
# Scholar title:  analise de sentimentos em discussoes de issues reabertas do github
#
# [196/231] Similarity: 1.0. Citations: 3.
# Original title: bulner: bug localization with word embeddings and network regularization
# Scholar title:  bulner: bug localization with word embeddings and network regularization
#
# [197/231] Similarity: 1.0. Citations: 0.
# Original title: analise e melhoria do processo de reengenharia de software: um estudo de caso
# Scholar title:  analise e melhoria do processo de reengenharia de software: um estudo de caso
#
# [198/231] Similarity: 1.0. Citations: 2.
# Original title: uma analise da relacao entre code smells e divida tecnica auto-admitida
# Scholar title:  uma analise da relacao entre code smells e divida tecnica auto-admitida
#
# [199/231] Similarity: 1.0. Citations: 0.
# Original title: clustering similarity measures for architecture recovery of evolving software
# Scholar title:  clustering similarity measures for architecture recovery of evolving software
#
# [200/231] Similarity: 1.0. Citations: 1.
# Original title: how workspaces influence software development? preliminary results of a systematic literature review
# Scholar title:  how workspaces influence software development? preliminary results of a systematic literature review
#
# [201/231] Similarity: 1.0. Citations: 1.
# Original title: um relato sobre a migracao de uma plataforma de offloading para microsservicos
# Scholar title:  um relato sobre a migracao de uma plataforma de offloading para microsservicos
#
# [202/231] Similarity: 1.0. Citations: 3.
# Original title: visualizing the maintainability of feature models in spls
# Scholar title:  visualizing the maintainability of feature models in spls
#
# [203/231] Similarity: 1.0. Citations: 0.
# Original title: analisando estrategias para identificacao de dividas tecnicas
# Scholar title:  analisando estrategias para identificacao de dividas tecnicas
#
# [204/231] Similarity: 1.0. Citations: 0.
# Original title: proposta de uma abordagem para decompor sistemas monoliticos em microsservicos
# Scholar title:  proposta de uma abordagem para decompor sistemas monoliticos em microsservicos
#
# [205/231] Similarity: 1.0. Citations: 1.
# Original title: data-flow analysis heuristic for vulnerability detection on configurable systems
# Scholar title:  data-flow analysis heuristic for vulnerability detection on configurable systems
#
# [206/231] Similarity: 1.0. Citations: 1.
# Original title: quero lhe usar! uma analise do publico alvo de code samples
# Scholar title:  quero lhe usar! uma analise do publico alvo de code samples
#
# [207/231] Similarity: 1.0. Citations: 0.
# Original title: validacao e construcao de um dicionario lexico para auxiliar a analise de sentimentos em repositorios de projetos de software
# Scholar title:  validacao e construcao de um dicionario lexico para auxiliar a analise de sentimentos em repositorios de projetos de software
#
# [208/231] Similarity: 1.0. Citations: 1.
# Original title: contextual similarity among identifier names: an empirical study
# Scholar title:  contextual similarity among identifier names: an empirical study
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [209/231] Similarity: 1.0. Citations: 0.
# Original title: diffmutanalyze: uma ferramenta para auxiliar a analise dos mutantes equivalentes no ensino do teste de mutacao
# Scholar title:  diffmutanalyze: uma ferramenta para auxiliar a analise dos mutantes equivalentes no ensino do teste de mutacao
#
# [210/231] Similarity: 1.0. Citations: 1.
# Original title: caracterizando a evolucao de software de contratos inteligentes: um estudo exploratorio-descritivo utilizando github e etherscan
# Scholar title:  caracterizando a evolucao de software de contratos inteligentes: um estudo exploratorio-descritivo utilizando github e etherscan
#
# [211/231] Similarity: 1.0. Citations: 0.
# Original title: what do software team managers want from a skills identification?
# Scholar title:  what do software team managers want from a skills identification?
#
# [212/231] Similarity: 1.0. Citations: 0.
# Original title: minerando motivacoes para aplicacao de extract method: um estudo preliminar
# Scholar title:  minerando motivacoes para aplicacao de extract method: um estudo preliminar
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# All proxies failed. New proxy list: True.
# [213/231] Similarity: 0.5413533834586466. Citations: 0.
# Original title: investigating vulnerability datasets
# Scholar title:  investigating the impact of vulnerability datasets on deep learning-based vulnerability detectors
#
# Current proxy failed. Trying a new one.
# [214/231] Similarity: 1.0. Citations: 0.
# Original title: revealing developers' arguments on validating the incidence of code smells: a focus group experience
# Scholar title:  revealing developers' arguments on validating the incidence of code smells: a focus group experience
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [215/231] Similarity: 1.0. Citations: 0.
# Original title: uma analise da co-evolucao de teste em projetos de software no github
# Scholar title:  uma analise da co-evolucao de teste em projetos de software no github
#
# Current proxy failed. Trying a new one.
# [216/231] Similarity: 0.9873417721518988. Citations: 0.
# Original title: bohr - uma ferramenta para a identificacao de atomos de confusao em codigos java
# Scholar title:  bohr-uma ferramenta para a identificacao de atomos de confusao em codigos java
#
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [217/231] Similarity: 0.9941520467836257. Citations: 1.
# Original title: readability and understandability scores for snippet assessment: an exploratory study
# Scholar title:  readability and understandability scores for snippet assessment: an exploratory study.
#
# All proxies failed. New proxy list: True.
# [218/231] Similarity: 1.0. Citations: 0.
# Original title: say my name! an empirical study on the pronounceability of identifier names
# Scholar title:  say my name! an empirical study on the pronounceability of identifier names
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [219/231] Similarity: 0.975609756097561. Citations: 0.
# Original title: bad smells in javascript - a mapping study
# Scholar title:  bad smells in javascript-a mapping study
#
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [220/231] Similarity: 1.0. Citations: 0.
# Original title: assessing the occurrence of blocking operations in database schema evolution: a case study
# Scholar title:  assessing the occurrence of blocking operations in database schema evolution: a case study
#
# Current proxy failed. Trying a new one.
# [221/231] Similarity: 0.5780346820809249. Citations: 0.
# Original title: avaliacao de ferramentas de identificacao de divida tecnica auto-admitida
# Scholar title:  uma abordagem de priorizacao para apoiar o pagamento de divida tecnica auto-admitida em codigo-fonte
#
# [222/231] Similarity: 0.3875. Citations: 0.
# Original title: como os mantenedores usam github reactions? um estudo exploratorio
# Scholar title:  an exploratory study on developers opinions about influence in open source software ecosystems
#
# All proxies failed. New proxy list: True.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# Current proxy failed. Trying a new one.
# [223/231] Similarity: 0.4. Citations: 0.
# Original title: concad: a tool for interactive code anomaly detection
# Scholar title:  tiseg: a flexible software tool for time-series generation of modis data utilizing the quality assessment science data set
#
# [224/231] Similarity: 0.5316455696202531. Citations: 0.
# Original title: democracia em xeque: um estudo comparativo sobre deteccao de code smells
# Scholar title:  entre o rosa eo azul: um estudo em representacoes sociais de ser homem e de ser mulher
#
# [225/231] Similarity: 0.3898305084745763. Citations: 0.
# Original title: divinator: a visual studio code extension to source code summarization
# Scholar title:  the ecclesiastical edicts of the theodosian code
#
# [226/231] Similarity: 0.6011560693641619. Citations: 0.
# Original title: empirical investigation of the influence of continuous integration bad practices on software quality
# Scholar title:  metrics to mesure the impact of continuous integration-an empirical study
#
# [227/231] Similarity: 0.4385026737967914. Citations: 0.
# Original title: entendendo o engajamento das comunidades front-end e back-end nos repositorios do github
# Scholar title:  o papel da documentacao no desenvolvimento de so wares open source: uma analise e um estudo de caso
#
# [228/231] Similarity: 0.40384615384615385. Citations: 0.
# Original title: exploring pull requests in code samples
# Scholar title:  an exploratory study of the pull-based software development model
#
# [229/231] Similarity: 0.4. Citations: 0.
# Original title: merge nature: a tool to support research about merge conflicts
# Scholar title:  on the nature of merge conflicts: a study of 2,731 open source java projects hosted by github
#
# [230/231] Similarity: 0.39759036144578314. Citations: 0.
# Original title: perceptions and difficulties of software engineering students in code smells refactoring
# Scholar title:  do they really smell bad? a study on developers' perception of bad code smells
#
# [231/231] Similarity: 0.5538461538461539. Citations: 0.
# Original title: using controllers to adapt messaging systems: an initial experience
# Scholar title:  integrating message-passing and shared-memory: early experience

# %%
df.to_excel('publications.xlsx', index=False)
